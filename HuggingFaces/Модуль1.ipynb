# %% [markdown]
# <a href="https://colab.research.google.com/github/delhian/NLP_course/blob/master/HuggingFaces/%D0%9C%D0%BE%D0%B4%D1%83%D0%BB%D1%8C1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
from transformers import pipeline
# Out:
# ...
#      |████████████████████████████████| 3.5 MB 8.1 MB/s
# ...
#      |████████████████████████████████| 895 kB 60.0 MB/s
# ...
#      |████████████████████████████████| 596 kB 64.7 MB/s
# ...
#      |████████████████████████████████| 67 kB 6.6 MB/s
# ...
#      |████████████████████████████████| 6.8 MB 64.6 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %% [markdown]
# Тематическая классификация

# %%
cls_pl = pipeline("text-classification", "nateraw/bert-base-uncased-ag-news")
cls_pl('He''s got the most beautiful green eyes," Francie Pelletier said, a little dreamily.')
# Out:
# [{'label': 'Sci/Tech', 'score': 0.3282374143600464}]

# %% [markdown]
# Token classification

# %%
ner_pipeline = pipeline("ner", "dslim/bert-base-NER", aggregation_strategy="first")
ner_pipeline("It had been written across the Mustang's windshield in hot-pink spray-paint, probably from his own garage.")
# Out:
# [{'end': 38,
#   'entity_group': 'MISC',
#   'score': 0.62343264,
#   'start': 31,
#   'word': 'Mustang'}]

# %% [markdown]
# Перевод с русского на английский

# %%
ru_en_translator = pipeline("translation_ru_to_en", "facebook/wmt19-ru-en")
ru_en_translator("Мэтью Кэрриган - инженер-механик в компании Hugging Face. Он живет в Дублине, Ирландия, а до этого работал инженером-программистом в Parse.ly, а до этого - постдоком-исследователем в дублинском колледже Trinity College.")
# Out:
# Downloading:   0%|          | 0.00/826 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.08G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/67.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/758k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/624k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/387k [00:00<?, ?B/s]
# [{'translation_text': 'Matthew Kerrigan is a mechanical engineer at Hugging Face. He lives in Dublin, Ireland, and previously worked as a software engineer at Parse.ly and as a postdoctoral researcher at Trinity College in Dublin.'}]

# %% [markdown]
# Перевод с английского на русский

# %%
txt = "Matthew Carrigan is a Machine Learning Engineer at Hugging Face. He lives in Dublin, Ireland and previously worked as an ML engineer at Parse.ly and before that as a post-doctoral researcher at Trinity College Dublin."
en_ru_translator = pipeline("translation_ru_to_en", "facebook/wmt19-en-ru")
en_ru_translator(txt)
# Out:
# Downloading:   0%|          | 0.00/827 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.08G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/67.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/624k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/758k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/308k [00:00<?, ?B/s]
# [{'translation_text': 'Мэтью Кэрриган - инженер-механик в компании Hugging Face. Он живет в Дублине, Ирландия, а до этого работал инженером-программистом в Parse.ly, а до этого - постдоком-исследователем в дублинском колледже Trinity College.'}]

# %% [markdown]
# Аннотирование

# %%
sum_pipeline = pipeline("summarization", "IlyaGusev/rut5_base_sum_gazeta")
sum_pipeline("Естественным развитием задач классификации всего текста или его фрагментов является классификация отдельных слов в предложении. Наиболее распространенной задачей такого вида является задача выделения именованных сущностей (NER - named entity recognition) - в данном случае необходимо для каждого слова в тексте проставить класс принадлежности его к тому или иному типу сущности (например, организация, персона, локация и т.д.), либо пустой класс, показывающий, что слово не относится ни к одному из рассматриваемых классов. С помощью NER можно разрабатывать системы автоматического заполнения форм документов, составления отчетов о компаниях, нахождения разных упоминания одних и тех же сущностей (это задача entity linking - она решается после ner), удаления персональной информации из текстов и т.д. Кроме классификации слов текста на именованные сущности, можно производить классификацию по каким-то другим критериям - например, по частям речи (хотя это практическое использование такого рода задач гораздо уже).")
# Out:
# Downloading:   0%|          | 0.00/766 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/932M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/279 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/808k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.25M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# [{'summary_text': 'Задача классификации всего текста или его фрагментов является задачей выделения именованных сущностей (NER), которая позволяет разрабатывать системы автоматического заполнения форм документов, составления отчетов о компаниях, удаления персональной информации из текстов и т.д.'}]

# %% [markdown]
# Поиск ответа на вопрос

# %%
qa_pipeline = pipeline("question-answering", "AlexKay/xlm-roberta-large-qa-multilingual-finedtuned-ru")
question = "Какая задача может быть развитием задачи классификации текста?"
context = "Естественным развитием задач классификации всего текста или его фрагментов является классификация отдельных слов в предложении."
qa_pipeline(question, context)
# Out:
# {'answer': ' классификация отдельных слов в предложении.',
#  'end': 127,
#  'score': 0.6581536531448364,
#  'start': 83}

# %%
question = "Что послужило основным толчком для существенного улучшения качества решения NLP задач в последние несколько лет?"
context = "Именно эта задача является одной из основных в NLP, и прорыв в качестве решения NLP задач в последние 3-4 года обусловлен именно новыми подходами к отображению текстов в векторное пространство. ( Однако задача тематической генерации достаточно успешно решалась с использованием достаточно простых статистических методов моделирования текста, которые будут рассмотрены в следующих модулях курса)."
qa_pipeline(question, context)
# Out:
# {'answer': ' новыми подходами к отображению текстов',
#  'end': 167,
#  'score': 0.04015088081359863,
#  'start': 128}

# %%
question = "Что служит входными данными для задачи поиска ответа на вопрос в заданном контексте?"
context = "Рассмотрим подробнее задачу в постановке поиска ответа на вопрос в заданном контексте. Если для рассмотренных ранее задач входными данными были только тексты, которые необходимо проанализировать, то в данном случае на вход подается два текста — вопрос и контекст, в котором необходимо найти ответ на вопрос (или, в некоторых случаях, указать, что его нет)."
qa_pipeline(question, context)
# Out:
# {'answer': ' тексты, которые необходимо проанализировать,',
#  'end': 195,
#  'score': 0.22161567211151123,
#  'start': 150}

# %%
question = "Какие NLP задачи успешно решались с использованием классических статистических методов?"
context = "Однако задача тематической генерации достаточно успешно решалась с использованием достаточно простых статистических методов моделирования текста, которые будут рассмотрены в следующих модулях курса"
qa_pipeline(question, context)
# Out:
# {'answer': ' тематической генерации',
#  'end': 36,
#  'score': 0.5020667910575867,
#  'start': 13}
